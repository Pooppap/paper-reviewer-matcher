# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
excel = pd.read_excel("data/Bayreuth Digital Science Conference_Abstracts.xlsx", sheet_name="Grouping")

# %%
keywords = excel["Keywords"]
keywords
# Out:
# 0         AI Clinician\n    Reinforcement learning\n...
# 1     sepsis, life-threatening condition, infection,...
# 2     Emergency hospital admissions, healthcare reco...
# 3     AI-based decision support systems, reinforceme...
# 4     early cancer prevention, diagnostics, clinical...
#                             ...
# 90    Acoustic levitation displays, ultrasonic waves...
# 91    Open schooling, zero-energy educational buildi...
# 92    Digital portal, Deeper Learning, Collaborative...
# 93    reinforcement learning, state abstraction, tem...
# 94    Deep Learning, IMU system, system validation, ...
# Name: Keywords, Length: 95, dtype: object

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for val in keywords:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(
    width = 2000, height = 2000,
    background_color ='white',
    stopwords = stopwords,
    min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize = (20, 20), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
