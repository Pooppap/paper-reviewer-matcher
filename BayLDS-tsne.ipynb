# %%
import pandas as pd

# %%
from yellowbrick.text import TSNEVisualizer
from yellowbrick.datasets import load_hobbies
from sklearn.feature_extraction.text import TfidfVectorizer

from matplotlib import pyplot as plt

# %%
excel = pd.read_excel("data/Bayreuth Digital Science Conference_Abstracts.xlsx", sheet_name="Grouping")

# %%
topics = excel["Topic"]
topics
# Out:
# 0     Digital Healthcare
# 1     Digital Healthcare
# 2     Digital Healthcare
# 3     Digital Healthcare
# 4     Digital Healthcare
#              ...
# 90        Control theory
# 91             Education
# 92             Education
# 93    Digital Healthcare
# 94    Digital Healthcare
# Name: Topic, Length: 95, dtype: object

# %%
abstracts = excel["Abstract"]
abstracts
# Out:
# 0     \nBackground. \nOur AI Clinician reinforcement...
# 1     Sepsis is a life-threatening condition that ca...
# 2     Emergency hospital admissions are straining he...
# 3     Promising results have been shown on AI-based ...
# 4     Early cancer prevention and diagnostics are ty...
#                             ...
# 90    Acoustic levitation displays use ultrasonic wa...
# 91    The Erasmus+ project acronymed NEB-LAB combine...
# 92    STEAM education is about engaging students in ...
# 93    Hierarchical Reinforcement Learning (HRL) algo...
# 94    An essential task in early stroke care is regu...
# Name: Abstract, Length: 95, dtype: object

# %%
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(abstracts)
y = topics

# %%
fig, ax = plt.subplots(figsize=(11, 10))
tsne = TSNEVisualizer(ax=ax, font_size=20, s=20)
tsne.fit(X, y)
tsne.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:title={'center':'TSNE Projection of 95 Documents'}>
